# %% [markdown]
# # Static Graph Rendering with plot_static()
#
# Render graphs as static images (SVG, PNG) for documentation, reports, and presentations.
#
# **Key point**: `plot_static()` works with **any layout** - UMAP, ring, graphviz, or manual positions.

# %%
import pandas as pd
import graphistry

# Sample graph
edges_df = pd.DataFrame({'src': ['a', 'a', 'b', 'c', 'd'], 'dst': ['b', 'c', 'c', 'd', 'e']})
nodes_df = pd.DataFrame({
    'id': ['a', 'b', 'c', 'd', 'e'],
    'type': ['start', 'middle', 'middle', 'middle', 'end'],
    'label': ['Start', 'Step 1', 'Step 2', 'Step 3', 'End']
})
g = graphistry.edges(edges_df, 'src', 'dst').nodes(nodes_df, 'id')

# %% [markdown]
# ## Basic Usage
#
# Auto-displays in Jupyter, returns SVG bytes:

# %%
g.plot_static()
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="no"?>\n<!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"\n "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">\n<!-- Generated by graphviz version 2.42.4 (0)\n -->\n<!-- Pages: 1 -->\n<svg width="124pt" height="332pt"\n viewBox="0.00 0.00 124.00 332.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">\n<g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 328)">\n<polygon fill="white" stroke="transparent" points="-4,4 -4,-328 120,-328 120,4 -4,4"/>\n<!-- a -->\n<g id="a" class="node">\n<title>a</title>\n<ellipse fill="none" stroke="black" cx="75" cy="-306" rx="34.5" ry="18"/>\n<text text-anchor="middle" x="75" y="-302.3" font-family="Times,serif" font-size="14.00">Start</text>\n</g>\n<!-- b -->\n<g id="b" class="node">\n<title>b</title>\n<ellipse fill="none" stroke="black" cx="41" cy="-234" rx="41" ry="18"/>\n<text text-anchor="middle" x="41" y="-230.3" font-family="Times,serif" font-size="14.00">Step 1</text>\n</g>\n<!-- a&#45;&gt;b -->\n<g id="edge1" class="edge">\n<title>a&#45;&gt;b</title>\n<path fill="none" stroke="black" d="M66.94,-288.41C62.98,-280.25 58.11,-270.22 53.66,-261.07"/>\n<polygon fill="black" stroke="black" points="56.75,-259.43 49.24,-251.96 50.46,-262.48 56.75,-259.43"/>\n</g>\n<!-- c -->\n<g id="c" class="node">\n<title>c</title>\n<ellipse fill="none" stroke="black" cx="75" cy="-162" rx="41" ry="18"/>\n<text text-anchor="middle" x="75" y="-158.3" font-family="Times,serif" font-size="14.00">Step 2</text>\n</g>\n<!-- a&#45;&gt;c -->\n<g id="edge2" class="edge">\n<title>a&#45;&gt;c</title>\n<path fill="none" stroke="black" d="M81.49,-288.1C85.08,-277.84 89.17,-264.36 91,-252 93.34,-236.17 93.34,-231.83 91,-216 89.7,-207.21 87.26,-197.86 84.66,-189.5"/>\n<polygon fill="black" stroke="black" points="87.95,-188.3 81.49,-179.9 81.3,-190.49 87.95,-188.3"/>\n</g>\n<!-- b&#45;&gt;c -->\n<g id="edge3" class="edge">\n<title>b&#45;&gt;c</title>\n<path fill="none" stroke="black" d="M49.23,-216.05C53.2,-207.89 58.04,-197.91 62.46,-188.82"/>\n<polygon fill="black" stroke="black" points="65.62,-190.31 66.85,-179.79 59.33,-187.25 65.62,-190.31"/>\n</g>\n<!-- d -->\n<g id="d" class="node">\n<title>d</title>\n<ellipse fill="none" stroke="black" cx="75" cy="-90" rx="41" ry="18"/>\n<text text-anchor="middle" x="75" y="-86.3" font-family="Times,serif" font-size="14.00">Step 3</text>\n</g>\n<!-- c&#45;&gt;d -->\n<g id="edge4" class="edge">\n<title>c&#45;&gt;d</title>\n<path fill="none" stroke="black" d="M75,-143.7C75,-135.98 75,-126.71 75,-118.11"/>\n<polygon fill="black" stroke="black" points="78.5,-118.1 75,-108.1 71.5,-118.1 78.5,-118.1"/>\n</g>\n<!-- e -->\n<g id="e" class="node">\n<title>e</title>\n<ellipse fill="none" stroke="black" cx="75" cy="-18" rx="29.5" ry="18"/>\n<text text-anchor="middle" x="75" y="-14.3" font-family="Times,serif" font-size="14.00">End</text>\n</g>\n<!-- d&#45;&gt;e -->\n<g id="edge5" class="edge">\n<title>d&#45;&gt;e</title>\n<path fill="none" stroke="black" d="M75,-71.7C75,-63.98 75,-54.71 75,-46.11"/>\n<polygon fill="black" stroke="black" points="78.5,-46.1 75,-36.1 71.5,-46.1 78.5,-46.1"/>\n</g>\n</g>\n</svg>\n'

# %% [markdown]
# ## Styling with graph_attr, node_attr, edge_attr

# %%
g.plot_static(
    graph_attr={'rankdir': 'LR', 'bgcolor': 'white'},
    node_attr={'shape': 'box', 'style': 'rounded,filled', 'fillcolor': 'lightblue'},
    edge_attr={'color': 'gray'}
)
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="no"?>\n<!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"\n "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">\n<!-- Generated by graphviz version 2.42.4 (0)\n -->\n<!-- Pages: 1 -->\n<svg width="449pt" height="67pt"\n viewBox="0.00 0.00 449.00 67.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">\n<g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 63)">\n<polygon fill="white" stroke="transparent" points="-4,4 -4,-63 445,-63 445,4 -4,4"/>\n<!-- a -->\n<g id="a" class="node">\n<title>a</title>\n<path fill="lightblue" stroke="black" d="M42,-36C42,-36 12,-36 12,-36 6,-36 0,-30 0,-24 0,-24 0,-12 0,-12 0,-6 6,0 12,0 12,0 42,0 42,0 48,0 54,-6 54,-12 54,-12 54,-24 54,-24 54,-30 48,-36 42,-36"/>\n<text text-anchor="middle" x="27" y="-14.3" font-family="Times,serif" font-size="14.00">Start</text>\n</g>\n<!-- b -->\n<g id="b" class="node">\n<title>b</title>\n<path fill="lightblue" stroke="black" d="M141,-59C141,-59 102,-59 102,-59 96,-59 90,-53 90,-47 90,-47 90,-35 90,-35 90,-29 96,-23 102,-23 102,-23 141,-23 141,-23 147,-23 153,-29 153,-35 153,-35 153,-47 153,-47 153,-53 147,-59 141,-59"/>\n<text text-anchor="middle" x="121.5" y="-37.3" font-family="Times,serif" font-size="14.00">Step 1</text>\n</g>\n<!-- a&#45;&gt;b -->\n<g id="edge1" class="edge">\n<title>a&#45;&gt;b</title>\n<path fill="none" stroke="gray" d="M54.26,-24.53C62.33,-26.54 71.41,-28.79 80.2,-30.98"/>\n<polygon fill="gray" stroke="gray" points="79.37,-34.38 89.92,-33.4 81.06,-27.59 79.37,-34.38"/>\n</g>\n<!-- c -->\n<g id="c" class="node">\n<title>c</title>\n<path fill="lightblue" stroke="black" d="M240,-36C240,-36 201,-36 201,-36 195,-36 189,-30 189,-24 189,-24 189,-12 189,-12 189,-6 195,0 201,0 201,0 240,0 240,0 246,0 252,-6 252,-12 252,-12 252,-24 252,-24 252,-30 246,-36 240,-36"/>\n<text text-anchor="middle" x="220.5" y="-14.3" font-family="Times,serif" font-size="14.00">Step 2</text>\n</g>\n<!-- a&#45;&gt;c -->\n<g id="edge2" class="edge">\n<title>a&#45;&gt;c</title>\n<path fill="none" stroke="gray" d="M54.23,-15.93C65.27,-15.16 78.25,-14.38 90,-14 117.99,-13.1 125.01,-13.16 153,-14 161.3,-14.25 170.18,-14.67 178.65,-15.15"/>\n<polygon fill="gray" stroke="gray" points="178.54,-18.65 188.73,-15.76 178.96,-11.67 178.54,-18.65"/>\n</g>\n<!-- b&#45;&gt;c -->\n<g id="edge3" class="edge">\n<title>b&#45;&gt;c</title>\n<path fill="none" stroke="gray" d="M153.19,-33.72C161.33,-31.79 170.24,-29.68 178.82,-27.64"/>\n<polygon fill="gray" stroke="gray" points="179.76,-31.02 188.68,-25.31 178.14,-24.21 179.76,-31.02"/>\n</g>\n<!-- d -->\n<g id="d" class="node">\n<title>d</title>\n<path fill="lightblue" stroke="black" d="M339,-36C339,-36 300,-36 300,-36 294,-36 288,-30 288,-24 288,-24 288,-12 288,-12 288,-6 294,0 300,0 300,0 339,0 339,0 345,0 351,-6 351,-12 351,-12 351,-24 351,-24 351,-30 345,-36 339,-36"/>\n<text text-anchor="middle" x="319.5" y="-14.3" font-family="Times,serif" font-size="14.00">Step 3</text>\n</g>\n<!-- c&#45;&gt;d -->\n<g id="edge4" class="edge">\n<title>c&#45;&gt;d</title>\n<path fill="none" stroke="gray" d="M252.19,-18C260.24,-18 269.05,-18 277.54,-18"/>\n<polygon fill="gray" stroke="gray" points="277.68,-21.5 287.68,-18 277.68,-14.5 277.68,-21.5"/>\n</g>\n<!-- e -->\n<g id="e" class="node">\n<title>e</title>\n<path fill="lightblue" stroke="black" d="M429,-36C429,-36 399,-36 399,-36 393,-36 387,-30 387,-24 387,-24 387,-12 387,-12 387,-6 393,0 399,0 399,0 429,0 429,0 435,0 441,-6 441,-12 441,-12 441,-24 441,-24 441,-30 435,-36 429,-36"/>\n<text text-anchor="middle" x="414" y="-14.3" font-family="Times,serif" font-size="14.00">End</text>\n</g>\n<!-- d&#45;&gt;e -->\n<g id="edge5" class="edge">\n<title>d&#45;&gt;e</title>\n<path fill="none" stroke="gray" d="M351.04,-18C359.27,-18 368.26,-18 376.77,-18"/>\n<polygon fill="gray" stroke="gray" points="376.83,-21.5 386.83,-18 376.83,-14.5 376.83,-21.5"/>\n</g>\n</g>\n</svg>\n'

# %% [markdown]
# ## Per-Node Styling (Data-Driven)
#
# Add graphviz attribute columns to your dataframe:

# %%
nodes_styled = nodes_df.copy()
nodes_styled['fillcolor'] = nodes_styled['type'].map({
    'start': 'lightgreen', 'middle': 'lightblue', 'end': 'lightyellow'
})
nodes_styled['shape'] = 'box'

g_styled = graphistry.edges(edges_df, 'src', 'dst').nodes(nodes_styled, 'id')
g_styled.plot_static(graph_attr={'rankdir': 'LR'}, node_attr={'style': 'filled'})
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="no"?>\n<!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"\n "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">\n<!-- Generated by graphviz version 2.42.4 (0)\n -->\n<!-- Pages: 1 -->\n<svg width="449pt" height="67pt"\n viewBox="0.00 0.00 449.00 67.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">\n<g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 63)">\n<polygon fill="white" stroke="transparent" points="-4,4 -4,-63 445,-63 445,4 -4,4"/>\n<!-- a -->\n<g id="a" class="node">\n<title>a</title>\n<polygon fill="lightgreen" stroke="black" points="54,-36 0,-36 0,0 54,0 54,-36"/>\n<text text-anchor="middle" x="27" y="-14.3" font-family="Times,serif" font-size="14.00">Start</text>\n</g>\n<!-- b -->\n<g id="b" class="node">\n<title>b</title>\n<polygon fill="lightblue" stroke="black" points="153,-59 90,-59 90,-23 153,-23 153,-59"/>\n<text text-anchor="middle" x="121.5" y="-37.3" font-family="Times,serif" font-size="14.00">Step 1</text>\n</g>\n<!-- a&#45;&gt;b -->\n<g id="edge1" class="edge">\n<title>a&#45;&gt;b</title>\n<path fill="none" stroke="black" d="M54.26,-24.53C62.33,-26.54 71.41,-28.79 80.2,-30.98"/>\n<polygon fill="black" stroke="black" points="79.37,-34.38 89.92,-33.4 81.06,-27.59 79.37,-34.38"/>\n</g>\n<!-- c -->\n<g id="c" class="node">\n<title>c</title>\n<polygon fill="lightblue" stroke="black" points="252,-36 189,-36 189,0 252,0 252,-36"/>\n<text text-anchor="middle" x="220.5" y="-14.3" font-family="Times,serif" font-size="14.00">Step 2</text>\n</g>\n<!-- a&#45;&gt;c -->\n<g id="edge2" class="edge">\n<title>a&#45;&gt;c</title>\n<path fill="none" stroke="black" d="M54.23,-15.93C65.27,-15.16 78.25,-14.38 90,-14 117.99,-13.1 125.01,-13.16 153,-14 161.3,-14.25 170.18,-14.67 178.65,-15.15"/>\n<polygon fill="black" stroke="black" points="178.54,-18.65 188.73,-15.76 178.96,-11.67 178.54,-18.65"/>\n</g>\n<!-- b&#45;&gt;c -->\n<g id="edge3" class="edge">\n<title>b&#45;&gt;c</title>\n<path fill="none" stroke="black" d="M153.19,-33.72C161.33,-31.79 170.24,-29.68 178.82,-27.64"/>\n<polygon fill="black" stroke="black" points="179.76,-31.02 188.68,-25.31 178.14,-24.21 179.76,-31.02"/>\n</g>\n<!-- d -->\n<g id="d" class="node">\n<title>d</title>\n<polygon fill="lightblue" stroke="black" points="351,-36 288,-36 288,0 351,0 351,-36"/>\n<text text-anchor="middle" x="319.5" y="-14.3" font-family="Times,serif" font-size="14.00">Step 3</text>\n</g>\n<!-- c&#45;&gt;d -->\n<g id="edge4" class="edge">\n<title>c&#45;&gt;d</title>\n<path fill="none" stroke="black" d="M252.19,-18C260.24,-18 269.05,-18 277.54,-18"/>\n<polygon fill="black" stroke="black" points="277.68,-21.5 287.68,-18 277.68,-14.5 277.68,-21.5"/>\n</g>\n<!-- e -->\n<g id="e" class="node">\n<title>e</title>\n<polygon fill="lightyellow" stroke="black" points="441,-36 387,-36 387,0 441,0 441,-36"/>\n<text text-anchor="middle" x="414" y="-14.3" font-family="Times,serif" font-size="14.00">End</text>\n</g>\n<!-- d&#45;&gt;e -->\n<g id="edge5" class="edge">\n<title>d&#45;&gt;e</title>\n<path fill="none" stroke="black" d="M351.04,-18C359.27,-18 368.26,-18 376.77,-18"/>\n<polygon fill="black" stroke="black" points="376.83,-21.5 386.83,-18 376.83,-14.5 376.83,-21.5"/>\n</g>\n</g>\n</svg>\n'

# %% [markdown]
# ## Layout Programs
#
# | Program | Best For |
# |---------|----------|
# | `dot` | Hierarchies, DAGs |
# | `neato` | Small undirected graphs |
# | `circo` | Circular layouts |

# %%
g.plot_static(prog='circo', node_attr={'style': 'filled', 'fillcolor': 'lightblue'})
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="no"?>\n<!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"\n "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">\n<!-- Generated by graphviz version 2.42.4 (0)\n -->\n<!-- Pages: 1 -->\n<svg width="444pt" height="171pt"\n viewBox="0.00 0.00 443.60 171.27" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">\n<g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 167.27)">\n<polygon fill="white" stroke="transparent" points="-4,4 -4,-167.27 439.6,-167.27 439.6,4 -4,4"/>\n<!-- a -->\n<g id="a" class="node">\n<title>a</title>\n<ellipse fill="lightblue" stroke="black" cx="41" cy="-18" rx="34.5" ry="18"/>\n<text text-anchor="middle" x="41" y="-14.3" font-family="Times,serif" font-size="14.00">Start</text>\n</g>\n<!-- b -->\n<g id="b" class="node">\n<title>b</title>\n<ellipse fill="lightblue" stroke="black" cx="41" cy="-145.27" rx="41" ry="18"/>\n<text text-anchor="middle" x="41" y="-141.57" font-family="Times,serif" font-size="14.00">Step 1</text>\n</g>\n<!-- a&#45;&gt;b -->\n<g id="edge1" class="edge">\n<title>a&#45;&gt;b</title>\n<path fill="none" stroke="black" d="M41,-36.23C41,-57.31 41,-92.25 41,-116.88"/>\n<polygon fill="black" stroke="black" points="37.5,-117.07 41,-127.07 44.5,-117.07 37.5,-117.07"/>\n</g>\n<!-- c -->\n<g id="c" class="node">\n<title>c</title>\n<ellipse fill="lightblue" stroke="black" cx="151.21" cy="-81.63" rx="41" ry="18"/>\n<text text-anchor="middle" x="151.21" y="-77.93" font-family="Times,serif" font-size="14.00">Step 2</text>\n</g>\n<!-- a&#45;&gt;c -->\n<g id="edge2" class="edge">\n<title>a&#45;&gt;c</title>\n<path fill="none" stroke="black" d="M64.38,-31.5C79.87,-40.44 100.44,-52.32 117.68,-62.27"/>\n<polygon fill="black" stroke="black" points="115.93,-65.3 126.34,-67.27 119.44,-59.24 115.93,-65.3"/>\n</g>\n<!-- b&#45;&gt;c -->\n<g id="edge3" class="edge">\n<title>b&#45;&gt;c</title>\n<path fill="none" stroke="black" d="M66.01,-130.83C81.23,-122.04 100.86,-110.7 117.45,-101.13"/>\n<polygon fill="black" stroke="black" points="119.4,-104.05 126.3,-96.02 115.89,-97.99 119.4,-104.05"/>\n</g>\n<!-- d -->\n<g id="d" class="node">\n<title>d</title>\n<ellipse fill="lightblue" stroke="black" cx="264.16" cy="-81.63" rx="41" ry="18"/>\n<text text-anchor="middle" x="264.16" y="-77.93" font-family="Times,serif" font-size="14.00">Step 3</text>\n</g>\n<!-- c&#45;&gt;d -->\n<g id="edge4" class="edge">\n<title>c&#45;&gt;d</title>\n<path fill="none" stroke="black" d="M192.31,-81.63C198.85,-81.63 205.69,-81.63 212.43,-81.63"/>\n<polygon fill="black" stroke="black" points="212.91,-85.13 222.91,-81.63 212.91,-78.13 212.91,-85.13"/>\n</g>\n<!-- e -->\n<g id="e" class="node">\n<title>e</title>\n<ellipse fill="lightblue" stroke="black" cx="406.35" cy="-81.63" rx="29.5" ry="18"/>\n<text text-anchor="middle" x="406.35" y="-77.93" font-family="Times,serif" font-size="14.00">End</text>\n</g>\n<!-- d&#45;&gt;e -->\n<g id="edge5" class="edge">\n<title>d&#45;&gt;e</title>\n<path fill="none" stroke="black" d="M305.29,-81.63C324.67,-81.63 347.68,-81.63 366.85,-81.63"/>\n<polygon fill="black" stroke="black" points="367.05,-85.13 377.05,-81.63 367.05,-78.13 367.05,-85.13"/>\n</g>\n</g>\n</svg>\n'

# %% [markdown]
# ## Output Formats

# %%
# DOT source text
dot = g.plot_static(engine='graphviz-dot')
print(dot[:200])
# Out:
# digraph "" {
# 	graph [bb="0,0,115.89,324"];
# 	node [label="\N"];
# 	a	[height=0.5,
# 		id=a,
# 		label=Start,
# 		pos="74.946,306",
# 		width=0.95686];
# 	b	[height=0.5,
# 		id=b,
# 		label="Step 1",
# 		pos="40.946,234"

# %%
# Mermaid DSL
mermaid = g.plot_static(engine='mermaid-code')
print(mermaid)
# Out:
# graph LR
#     a --> b
#     a --> c
#     b --> c
#     c --> d
#     d --> e

# %% [markdown]
# ## Finding More Options
#
# Discover available attributes:

# %%
from graphistry.plugins_types.graphviz_types import GRAPH_ATTRS, NODE_ATTRS, EDGE_ATTRS, PROGS
print('Progs:', PROGS[:6])
print('Node attrs (sample):', NODE_ATTRS[:8])
# Out:
# Progs: ['acyclic', 'ccomps', 'circo', 'dot', 'fdp', 'gc']
# Node attrs (sample): ['area', 'class', 'color', 'colorscheme', 'comment', 'distortion', 'fillcolor', 'fixedsize']

# %% [markdown]
# **External references**:
# - [Graphviz Attributes](https://graphviz.org/doc/info/attrs.html)
# - [Graphviz Shapes](https://graphviz.org/doc/info/shapes.html)
# - [Graphviz Colors](https://graphviz.org/doc/info/colors.html)
#
# ## See Also
#
# - [graphviz.ipynb](graphviz.ipynb) - Layout algorithms for interactive Graphistry viz
